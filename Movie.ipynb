# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("top-500-movies.csv")
df
# Out:
#      rank release_date                                        title  \
# 0       1   2019-04-23                            Avengers: Endgame
# 1       2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2       3   2015-04-22                      Avengers: Age of Ultron
# 3       4   2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4       5   2018-04-25                       Avengers: Infinity War
# ..    ...          ...                                          ...
# 495   496   2013-02-06                       A Good Day to Die Hard
# 496   497   2004-04-09                                    The Alamo
# 497   498   1995-12-22                             Cutthroat Island
# 498   499   2013-12-19              The Secret Life of Walter Mitty
# 499   500   2023-03-09                                           65
#
#                                                    url  production_cost  \
# 0           /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# ...

# %%
df.info()#The info method prints information about the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rank             500 non-null    int64
#  1   release_date     499 non-null    object
#  2   title            500 non-null    object
#  3   url              500 non-null    object
#  4   production_cost  500 non-null    int64
#  5   domestic_gross   500 non-null    int64
#  6   worldwide_gross  500 non-null    int64
#  7   opening_weekend  479 non-null    float64
#  8   mpaa             492 non-null    object
#  9   genre            495 non-null    object
#  10  theaters         479 non-null    float64
#  11  runtime          487 non-null    float64
#  12  year             499 non-null    float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 50.9+ KB

# %%
df.describe()#The describe() method returns description of the data in the DataFrame
# Out:
#              rank  production_cost  domestic_gross  worldwide_gross  \
# count  500.000000     5.000000e+02    5.000000e+02     5.000000e+02
# mean   250.500000     1.494954e+08    1.696114e+08     4.697776e+08
# std    144.481833     4.774040e+07    1.421642e+08     3.850620e+08
# min      1.000000     9.100000e+07    0.000000e+00     0.000000e+00
# 25%    125.750000     1.100000e+08    7.047110e+07     2.122188e+08
# 50%    250.500000     1.400000e+08    1.318470e+08     3.671458e+08
# 75%    375.250000     1.750000e+08    2.185998e+08     6.484251e+08
# max    500.000000     4.000000e+08    9.366622e+08     2.910371e+09
#
#        opening_weekend     theaters     runtime         year
# count     4.790000e+02   479.000000  487.000000   499.000000
# mean      5.429206e+07  3659.770355  121.885010  2011.394790
# std       4.619796e+07   546.018902   22.399642     6.560688
# min       4.855800e+04    30.000000   76.000000  1991.000000
# ...

# %%
df.isnull()#The isnull() method returns a DataFrame object where all the values are replaced with a Boolean value True for NULL values, and otherwise False.
# Out:
#       rank  release_date  title    url  production_cost  domestic_gross  \
# 0    False         False  False  False            False           False
# 1    False         False  False  False            False           False
# 2    False         False  False  False            False           False
# 3    False         False  False  False            False           False
# 4    False         False  False  False            False           False
# ..     ...           ...    ...    ...              ...             ...
# 495  False         False  False  False            False           False
# 496  False         False  False  False            False           False
# 497  False         False  False  False            False           False
# 498  False         False  False  False            False           False
# 499  False         False  False  False            False           False
#
#      worldwide_gross  opening_weekend   mpaa  genre  theaters  runtime   year
# ...

# %%
df.isnull().sum()#check is there any null value
# Out:
# rank                0
# release_date        1
# title               0
# url                 0
# production_cost     0
# domestic_gross      0
# worldwide_gross     0
# opening_weekend    21
# mpaa                8
# genre               5
# theaters           21
# runtime            13
# year                1
# dtype: int64

# %%
df.head()#The head() function is used to get the first 5 rows
# Out:
#    rank release_date                                        title  \
# 0     1   2019-04-23                            Avengers: Endgame
# 1     2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     3   2015-04-22                      Avengers: Age of Ultron
# 3     4   2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     5   2018-04-25                       Avengers: Infinity War
#
#                                                  url  production_cost  \
# 0         /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# 1  /movie/Pirates-of-the-Caribbean-On-Stranger-Ti...        379000000
# 2          /movie/Avengers-Age-of-Ultron#tab=summary        365000000
# 3  /movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=...        306000000
# 4           /movie/Avengers-Infinity-War#tab=summary        300000000
#
#    domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# 0       858373000       2797800564      357115007.0  PG-13     Action
# ...

# %%
df.tail() #The tail() function is used to get the last 5 rows
# Out:
#      rank release_date                            title  \
# 495   496   2013-02-06           A Good Day to Die Hard
# 496   497   2004-04-09                        The Alamo
# 497   498   1995-12-22                 Cutthroat Island
# 498   499   2013-12-19  The Secret Life of Walter Mitty
# 499   500   2023-03-09                               65
#
#                                                    url  production_cost  \
# 495                      /movie/Die-Hard-5#tab=summary         92000000
# 496                /movie/Alamo-The-(2004)#tab=summary         92000000
# 497                /movie/Cutthroat-Island#tab=summary         92000000
# 498  /movie/Secret-Life-of-Walter-Mitty-The-(2012)#...         91000000
# 499                       /movie/65-(2022)#tab=summary         91000000
#
#      domestic_gross  worldwide_gross  opening_weekend   mpaa  \
# 495        67349198        304249198       24834845.0      R
# 496        22406362         23911362        9124701.0  PG-13
# ...

# %%
df.genre=='Action'
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 495     True
# 496    False
# 497    False
# 498    False
# 499    False
# Name: genre, Length: 500, dtype: bool

# %%
df[df.title=="The Avengers"]
# Out:
#     rank release_date         title                                     url  \
# 29    30   2012-04-25  The Avengers  /movie/Avengers-The-(2012)#tab=summary
#
#     production_cost  domestic_gross  worldwide_gross  opening_weekend   mpaa  \
# 29        225000000       623357910       1515100211      207438708.0  PG-13
#
#      genre  theaters  runtime    year
# 29  Action    4349.0    143.0  2012.0

# %%
df[df.year==2018]
# Out:
#      rank release_date                                        title  \
# 4       5   2018-04-25                       Avengers: Infinity War
# 10     11   2018-05-23                      Solo: A Star Wars Story
# 47     48   2018-02-13                                Black Panther
# 49     50   2018-06-15                                Incredibles 2
# 73     74   2018-11-14  Fantastic Beasts: The Crimes of Grindelwald
# 118   119   2018-07-16                  Mission: Impossible—Fallout
# 120   121   2018-08-09                                      The Meg
# 129   130   2018-11-21                    Ralph Breaks The Internet
# 142   143   2018-06-06               Jurassic World: Fallen Kingdom
# 168   169   2018-12-06                                      Aquaman
# 184   185   2018-03-16                        Pacific Rim: Uprising
# 214   215   2018-03-20                             Ready Player One
# 277   278   2018-10-31           The Nutcracker and the Four Realms
# ...

# %%
df[df.release_date==2019]
df
# Out:
#      rank release_date                                        title  \
# 0       1   2019-04-23                            Avengers: Endgame
# 1       2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2       3   2015-04-22                      Avengers: Age of Ultron
# 3       4   2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4       5   2018-04-25                       Avengers: Infinity War
# ..    ...          ...                                          ...
# 495   496   2013-02-06                       A Good Day to Die Hard
# 496   497   2004-04-09                                    The Alamo
# 497   498   1995-12-22                             Cutthroat Island
# 498   499   2013-12-19              The Secret Life of Walter Mitty
# 499   500   2023-03-09                                           65
#
#                                                    url  production_cost  \
# 0           /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# ...

# %%
df[df.genre=='Action']
# Out:
#      rank release_date                         title  \
# 0       1   2019-04-23             Avengers: Endgame
# 2       3   2015-04-22       Avengers: Age of Ultron
# 4       5   2018-04-25        Avengers: Infinity War
# 6       7   2017-11-13                Justice League
# 7       8   2015-10-06                       Spectre
# ..    ...          ...                           ...
# 479   480   2010-11-12                   Unstoppable
# 480   481   1997-05-09             The Fifth Element
# 489   490   2015-01-29  Kingsman: The Secret Service
# 491   492   2001-07-18             Jurassic Park III
# 495   496   2013-02-06        A Good Day to Die Hard
#
#                                                 url  production_cost  \
# 0        /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# 2         /movie/Avengers-Age-of-Ultron#tab=summary        365000000
# 4          /movie/Avengers-Infinity-War#tab=summary        300000000
# ...

# %%
df[df.opening_weekend>=191271109.0]
# Out:
#     rank release_date                                 title  \
# 0      1   2019-04-23                     Avengers: Endgame
# 2      3   2015-04-22               Avengers: Age of Ultron
# 3      4   2015-12-16  Star Wars Ep. VII: The Force Awakens
# 4      5   2018-04-25                Avengers: Infinity War
# 13    14   2017-12-13     Star Wars Ep. VIII: The Last Jedi
# 14    15   2019-07-11                         The Lion King
# 29    30   2012-04-25                          The Avengers
# 37    38   2015-06-09                        Jurassic World
# 46    47   2021-12-14               Spider-Man: No Way Home
# 47    48   2018-02-13                         Black Panther
#
#                                                   url  production_cost  \
# 0          /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# 2           /movie/Avengers-Age-of-Ultron#tab=summary        365000000
# 3   /movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=...        306000000
# ...

# %%
df[['title','genre','runtime']]
# Out:
#                                            title              genre  runtime
# 0                              Avengers: Endgame             Action    181.0
# 1    Pirates of the Caribbean: On Stranger Tides          Adventure    136.0
# 2                        Avengers: Age of Ultron             Action    141.0
# 3           Star Wars Ep. VII: The Force Awakens          Adventure    136.0
# 4                         Avengers: Infinity War             Action    156.0
# ..                                           ...                ...      ...
# 495                       A Good Day to Die Hard             Action     98.0
# 496                                    The Alamo            Western    137.0
# 497                             Cutthroat Island          Adventure      NaN
# 498              The Secret Life of Walter Mitty          Adventure    114.0
# 499                                           65  Thriller/Suspense      NaN
#
# [500 rows x 3 columns]

# %%
Yrs=df["year"].sum()
RT=df["runtime"].sum()

# %%
plt.figure(figsize=(13,6))
data=[Yrs,RT]
labels=['genre','runtime']
color=sns.color_palette('Set2')
plt.pie(data,labels =labels,colors=color,autopct='%.0f%%')
plt.legend()
plt.show()

# %%
df['mpaa'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='mpaa'>

# %%
sns.relplot(x='theaters',y='rank',data=df)

# %%
sns.relplot(x='runtime',y='rank',data=df,kind='line')

# %%
df['runtime'].sum()
# Out:
# 59358.0

# %%
df['mpaa'].unique()
# Out:
# array(['PG-13', nan, 'PG', 'G', 'R', 'Unrated'], dtype=object)

# %%
sns.relplot(x='runtime',y='rank',data=df,hue='theaters')

# %%
sns.relplot(x='runtime',y='rank',data=df,hue='theaters',style='mpaa')

# %%
sns.scatterplot(x ="runtime",y ="rank",style ="mpaa",data = df)
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='rank'>

# %%
sns.catplot(x='mpaa',y='runtime',data=df)#mpaa=Motion Picture Association Of America

# %%
sns.barplot(x='mpaa',y='runtime',data=df)
# Out:
# <AxesSubplot:xlabel='mpaa', ylabel='runtime'>

# %%
sns.countplot(x='mpaa',data=df)
# Out:
# <AxesSubplot:xlabel='mpaa', ylabel='count'>

# %%
sns.catplot(x='mpaa',y='runtime',data=df,kind='swarm',hue='genre')
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.distplot(df['runtime'])
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='runtime', ylabel='Density'>

# %%
sns.distplot(df['production_cost'],kde=True)# KDE shows the density where the points match up the most
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='production_cost', ylabel='Density'>

# %%
sns.distplot(df['production_cost'],kde=True,hist=False)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='production_cost', ylabel='Density'>

# %%
sns.kdeplot(df['runtime'],shade=False,color='g',alpha=0.6)
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='Density'>

# %%
sns.jointplot(df['runtime'],df['production_cost'])
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(x ='runtime', y ='domestic_gross', data=df, kind ='kde')

# %%
sns.pairplot(df)

# %%
sns.boxplot(x ='mpaa', y ='runtime',data=df,hue='genre')
# Out:
# <AxesSubplot:xlabel='mpaa', ylabel='runtime'>

# %%
sns.violinplot(x ='mpaa', y ='opening_weekend',data=df)
# Out:
# <AxesSubplot:xlabel='mpaa', ylabel='opening_weekend'>

# %%
sns.stripplot(x ='mpaa', y ='production_cost',data=df)
# Out:
# <AxesSubplot:xlabel='mpaa', ylabel='production_cost'>

# %%
sns.stripplot(x ='mpaa', y ='production_cost',data=df,jitter = True,
 hue ='genre' ,dodge=True)
# Out:
# <AxesSubplot:xlabel='mpaa', ylabel='production_cost'>

# %%
sns.regplot(x='production_cost',y='opening_weekend',data=df)
# Out:
# <AxesSubplot:xlabel='production_cost', ylabel='opening_weekend'>

# %%
sns.regplot(x='runtime',y='opening_weekend',data=df)
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='opening_weekend'>

# %%
a=df.corr()
sns.heatmap(a)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),cmap='tab20')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),cmap='tab20',annot=True,linewidth=2,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),cmap='tab20',cbar=False,annot=True,linewidth=2,linecolor='black')
# Out:
# <AxesSubplot:>
